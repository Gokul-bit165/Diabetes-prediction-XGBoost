# %%
# %run dataprocessing.ipynb
# Out:
# Train set shape: (614, 8)
# Test set shape: (154, 8)

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6    148.0           72.0           35.0    125.0  33.6
# 1            1     85.0           66.0           29.0    125.0  26.6
# 2            8    183.0           64.0           29.0    125.0  23.3
# 3            1     89.0           66.0           23.0     94.0  28.1
# 4            0    137.0           40.0           35.0    168.0  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='Outcome', data=df, palette='Set2')
plt.title("Diabetes Outcome Distribution (0 = No, 1 = Yes)")
plt.show()
# Out:
# C:\Users\gokul\AppData\Local\Temp\ipykernel_33928\456764261.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Outcome', data=df, palette='Set2')

# %%
df.hist(figsize=(12,10), bins=30, edgecolor="black")
plt.suptitle("Feature Distributions", size=16)
plt.show()

# %%
plt.figure(figsize=(14,10))
for i, col in enumerate(df.drop("Outcome", axis=1).columns, 1):
    plt.subplot(3,3,i)
    sns.boxplot(x="Outcome", y=col, data=df, palette="Set3")
    plt.title(f"{col} vs Outcome")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\gokul\AppData\Local\Temp\ipykernel_33928\848572479.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Outcome", y=col, data=df, palette="Set3")
# C:\Users\gokul\AppData\Local\Temp\ipykernel_33928\848572479.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Outcome", y=col, data=df, palette="Set3")
# C:\Users\gokul\AppData\Local\Temp\ipykernel_33928\848572479.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Outcome", y=col, data=df, palette="Set3")
# C:\Users\gokul\AppData\Local\Temp\ipykernel_33928\848572479.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Outcome", y=col, data=df, palette="Set3")
# C:\Users\gokul\AppData\Local\Temp\ipykernel_33928\848572479.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Outcome", y=col, data=df, palette="Set3")
# C:\Users\gokul\AppData\Local\Temp\ipykernel_33928\848572479.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Outcome", y=col, data=df, palette="Set3")
# C:\Users\gokul\AppData\Local\Temp\ipykernel_33928\848572479.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Outcome", y=col, data=df, palette="Set3")
# C:\Users\gokul\AppData\Local\Temp\ipykernel_33928\848572479.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Outcome", y=col, data=df, palette="Set3")

# %%
plt.figure(figsize=(10,6))
corr = df.corr()
sns.heatmap(corr, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Feature Correlation Heatmap")
plt.show()
